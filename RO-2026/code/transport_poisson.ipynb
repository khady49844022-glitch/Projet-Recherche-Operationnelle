# %%
# ====================================
# TRANSPORT DE POISSON
# Nouadhibou -> Nouakchott
# ====================================

distance_km = 470

vitesse_camion = 80

temps = distance_km / vitesse_camion

capacite_camion = 1000

poisson_total = 5000

nombre_camions = poisson_total / capacite_camion

print("Temps de trajet :", temps, "heures")

print("Nombre de camions nécessaires :",
      nombre_camions)
# Out:
# Temps de trajet : 5.875 heures
# Nombre de camions nécessaires : 5.0
